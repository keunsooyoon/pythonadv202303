# %% [markdown]
# 스타벅스 크롤링 & 분석

# %%
from selenium import webdriver
import time
from bs4 import BeautifulSoup as bs
from selenium.webdriver.common.by import By
import pandas as pd

# %%
url = 'https://www.starbucks.co.kr/store/store_map.do'
driver = webdriver.Chrome('chromedriver.exe')
driver.get(url)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_10328\2862607696.py:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('chromedriver.exe')

# %%
area_btn = '#container > div > form > fieldset > div > section > article.find_store_cont > article > header.loca_search > h3 > a'
driver.find_element(By.CSS_SELECTOR,area_btn).click()

time.sleep(2)
seoul_btn = '#container > div > form > fieldset > div > section > article.find_store_cont > article > article:nth-child(4) > div.loca_step1 > div.loca_step1_cont > ul > li:nth-child(1) > a'
driver.find_element(By.CSS_SELECTOR,seoul_btn).click()

time.sleep(2)
all_btn = '#mCSB_2_container > ul > li:nth-child(1) > a'
driver.find_element(By.CSS_SELECTOR,all_btn).click()

# %%
txt = driver.page_source
html = bs(txt)

len(html.select('li'))
# Out:
# 1052

# %%
len(html.select('li.quickResultLstCon'))
# Out:
# 610

# %%
shops = html.select('li.quickResultLstCon')

# %%
shop = shops[0]
shop
# Out:
# <li class="quickResultLstCon" data-code="3218" data-hlytag="null" data-index="0" data-lat="37.553376" data-long="126.918564" data-name="서교동사거리" data-storecd="1031" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="서교동사거리" data-store="1031" data-yn="N">서교동사거리  </strong> <p class="result_details">서울특별시 마포구 양화로 105 (서교동)<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>

# %%
txt = driver.page_source
html = bs(txt)

len(html.select('li'))

shops = html.select('ul.quickSearchResultBoxSidoGugun > li.quickResultLstCon')
shop = shops[0]
shop
# Out:
# <li class="quickResultLstCon" data-code="3762" data-hlytag="null" data-index="0" data-lat="37.501087" data-long="127.043069" data-name="역삼아레나빌딩" data-storecd="1509" style="background:#fff"> <strong data-my_siren_order_store_yn="N" data-name="역삼아레나빌딩" data-store="1509" data-yn="N">역삼아레나빌딩  </strong> <p class="result_details">서울특별시 강남구 언주로 425 (역삼동)<br/>1522-3232</p> <i class="pin_general">리저브 매장 2번</i></li>

# %%
# 위도 : data-lat 딕셔너리 형태로 추출 즉 키값 밸류값
lat = shop['data-lat']

# 경도 : data-long 딕셔너리 형태로 추출 즉 키값 밸류값
lng = shop['data-long']

# 지점명 : data-name 딕셔너리 형태로 추출 즉 키값 밸류값
name = shop['data-name']

# <p class="result_details">서울특별시 마포구 양화로 105 (서교동)<br/>1522-3232</p>

# 주소 : 딕셔너리 형태가 아니기 때문에 select으로 추출
addr = str(shop.select('p.result_details')[0]).split('<br/>')[0].split('>')[1]

# 전화번호 : 주소와 전화번호는 묶여 있으므로 복잡하게 추출
tel = str(shop.select('p.result_details')[0]).split('<br/>')[1].split('<')[0]

# 매장종류 : 딕셔너리 형태가 아니기 때문에 select으로 추출
stype = shop.select('i.pin_general')[0].text


print(lat)
print(lng)
print(name)
print(addr)
print(tel)
print(stype)
# Out:
# 37.501087
# 127.043069
# 역삼아레나빌딩
# 서울특별시 강남구 언주로 425 (역삼동)
# 1522-3232
# 리저브 매장 2번

# %%
# ['매장명','위도','경도','주소','전화번호','매장종류']


starbucks_list = []

for shop in shops:
    lat = shop['data-lat']
    lng = shop['data-long']
    name = shop['data-name']
    addr = str(shop.select('p.result_details')[0]).split('<br/>')[0].split('>')[1]
    tel = str(shop.select('p.result_details')[0]).split('<br/>')[1].split('<')[0]
    stype = shop.select('i')[0].text

# 3                 서울특별시 강남구 테헤란로 125 (역삼동)  1522-3232  리저브 매장 2번
# 4               서울특별시 강남구 남부순환로 2947 (대치동)  1522-3232  리저브 매장 2번
# ..                                     ...        ...        ...
# 595                      서울특별시 중랑구 면목로 310  1522-3232  리저브 매장 2번
# 596                서울특별시 중랑구 망우로 307 (상봉동)  1522-3232  리저브 매장 2번
# 597  서울특별시 중랑구 동일로 952 (묵동, 로프트원 태릉입구역) 1층  1522-3232  리저브 매장 2번
# 598              서울특별시 중랑구 양원역로10길 3 (망우동)  1522-3232  리저브 매장 2번
# 599                     서울특별시 중랑구 봉화산로 35   1522-3232  리저브 매장 2번
#
# [600 rows x 6 columns]

# %%
df.to_excel('starbucks_seoul.xlsx', index = False)

# df = pd.read_excel('starbucks_seoul.xlsx', header=0)

# %%
############################################################
#                          데이터 분석                      #
############################################################

#!pip install folium

# %%
import folium

starmap = folium.Map()

starmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a8ff4cb786508ee7c462c5f0cd677c6a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a8ff4cb786508ee7c462c5f0cd677c6a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a8ff4cb786508ee7c462c5f0cd677c6a = L.map(
#                 &quot;map_a8ff4cb786508ee7c462c5f0cd677c6a&quot;,
#                 {
#                     center: [0, 0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 1,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5d2f1655057cb99dd5599122e7d14e6d = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_a8ff4cb786508ee7c462c5f0cd677c6a);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import folium

starmap = folium.Map(
    location=[37.5666805,126.9784147],  # 구글에서 검색한 서울 시청 좌표
    zoom_start=11
)

starmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8d844cd23437debcee9ac50ff693cfce {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8d844cd23437debcee9ac50ff693cfce&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8d844cd23437debcee9ac50ff693cfce = L.map(
#                 &quot;map_8d844cd23437debcee9ac50ff693cfce&quot;,
#                 {
#                     center: [37.5666805, 126.9784147],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_60ec7c501220fa2dd50acea2a28f182c = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_8d844cd23437debcee9ac50ff693cfce);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import folium

starmap = folium.Map(
    location=[37.5666805,126.9784147],  # 구글에서 검색한 서울 시청 좌표
    zoom_start=11,
    tiles='Stamen Watercolor'
)

# 타일 종류
# OpenStreetMap (기본값)
# Stamen Terrain, Stamen Toner, Stamen Watercolor
# CartoDB positron, CartoDB dark_matter

starmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3ee54abb8405caec24b754cd5eb4d758 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3ee54abb8405caec24b754cd5eb4d758&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3ee54abb8405caec24b754cd5eb4d758 = L.map(
#                 &quot;map_3ee54abb8405caec24b754cd5eb4d758&quot;,
#                 {
#                     center: [37.5666805, 126.9784147],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_106ab588f90537cb0a236c589f87557f = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/watercolor/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca target=\&quot;_blank\&quot; href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_3ee54abb8405caec24b754cd5eb4d758);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import folium

starmap = folium.Map(
    location=[37.5666805,126.9784147],  # 구글에서 검색한 서울 시청 좌표
    zoom_start=11,
    tiles='Stamen Terrain'
)

folium.Marker(
    location=[37.5666805,126.9784147],
    fill = True
).add_to(starmap)


starmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9558e5f3e17f314a134e2af2ce3dab3d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9558e5f3e17f314a134e2af2ce3dab3d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9558e5f3e17f314a134e2af2ce3dab3d = L.map(
#                 &quot;map_9558e5f3e17f314a134e2af2ce3dab3d&quot;,
#                 {
#                     center: [37.5666805, 126.9784147],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_edb828215b1d83ba04b735d5c56c08ed = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca target=\&quot;_blank\&quot; href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_9558e5f3e17f314a134e2af2ce3dab3d);
#
#
#             var marker_46ef90b48100622c88f6405bac917b96 = L.marker(
#                 [37.5666805, 126.9784147],
#                 {&quot;fill&quot;: true}
#             ).addTo(map_9558e5f3e17f314a134e2af2ce3dab3d);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import folium

starmap = folium.Map(
    location=[37.5666805,126.9784147],  # 구글에서 검색한 서울 시청 좌표
    zoom_start=11,
    tiles='Stamen Terrain'
)

# 데이터 프레임에서 위도와 경도 값을 가져와서 600번 반복

for idx in df.index:
    lat = df.loc[idx,'위도']
    lng = df.loc[idx,'경도']

    folium.Marker(
        location=[lat,lng],
        fill = True
    ).add_to(starmap)


starmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_73a1acf1c344d463876d32a7d0f5e2d8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_73a1acf1c344d463876d32a7d0f5e2d8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_73a1acf1c344d463876d32a7d0f5e2d8 = L.map(
#                 &quot;map_73a1acf1c344d463876d32a7d0f5e2d8&quot;,
#                 {
#                     center: [37.5666805, 126.9784147],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_88397a93998332f5b338671c777d4e5e = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/terrain/{z}/{x}/{y}.jpg&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca target=\&quot;_blank\&quot; href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://creativecommons.org/licenses/by-sa/3.0\&quot;\u003eCC BY SA\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_73a1acf1c344d463876d32a7d0f5e2d8);
#
#
#             var marker_a24e64fc14258e0163d322d761e3c84e = L.marker(
#                 [37.501087, 127.043069],
#                 {&quot;fill&quot;: true}
#             ).addTo(map_73a1acf1c344d463876d32a7d0f5e2d8);
#
#
#             var marker_98e0ac0f4be38c3b9065e8a6a5439031 = L.marker(
#                 [37.510178, 127.022223],
#                 {&quot;fill&quot;: true}
#             ).addTo(map_73a1acf1c344d463876d32a7d0f5e2d8);
#
#
#             var marker_1a7e4f51fbd79edf68c3726c0754acd6 = L.marker(
#                 [37.5139309, 127.0206057],
#                 {&quot;fill&quot;: true}
#             ).addTo(map_73a1acf1c344d463876d32a7d0f5e2d8);
#
#
#             var marker_6caa7cf009b64b8628914422a586263b = L.marker(
#                 [37.499517, 127.031495],
#                 {&quot;fill&quot;: true}
#             ).addTo(map_73a1acf1c344d463876d32a7d0f5e2d8);
#
#
#             var marker_0c23fba86c7badb9306c6d6dd6e4fbda = L.marker(
#                 [37.494668, 127.062583],
#                 {&quot;fill&quot;: true}
#             ).addTo(map_73a1acf1c344d463876d32a7d0f5e2d8);
#
#
#             var marker_a2ea567aa45b2e20dc2d3e45f0f6fd84 = L.marker(
#                 [37.515, 127.063196],
#                 {&quot;fill&quot;: true}
#             ).addTo(map_73a1acf1c344d463876d32a7d0f5e2d8);
#
#
#             var marker_d10675e4cf495587e19bfeecf197699b = L.marker(
#                 [37.5227934, 127.0286009],
#                 {&quot;fill&quot;: true}
#             ).addTo(map_73a1acf1c344d463876d32a7d0f5e2d8);
#
#
#             var marker_de8d2799c38a64722266ba82700c8dd3 = L.marker(
#                 [37.51015, 127.060275],
#                 {&quot;fill&quot;: true}
#             ).addTo(map_73a1acf1c344d463876d32a7d0f5e2d8);
#
#
#             var marker_7f2c036f5f91d338a575f6a2d3f559bf = L.marker(
#                 [37.50775, 127.060651],
#                 {&quot;fill&quot;: true}
#             ).addTo(map_73a1acf1c344d463876d32a7d0f5e2d8);
#
#
#             var marker_6bbbe4bb0342a2dedf76a4411ee7d99c = L.marker(
#                 [37.5273669, 127.033061],
#                 {&quot;fill&quot;: true}
#             ).addTo(map_73a1acf1c344d463876d32a7d0f5e2d8);
#
#
#             var marker_b7afe258794f7557ecc2ef2426858214 = L.marker(
#                 [37.488008, 127.10265],
#                 {&quot;fill&quot;: true}
#             ).addTo(map_73a1acf1c344d463876d32a7d0f5e2d8);
#
#
#             var marker_68c3d6e9902a79120b48db33aa099fe2 = L.marker(
#                 [37.485192, 127.036685],
#                 {&quot;fill&quot;: true}
#             ).addTo(map_73a1acf1c344d463876d32a7d0f5e2d8);
#
#
#             var marker_28b81257877f1513ef2e689ebb8cd29b = L.marker(
#                 [37.505321, 127.050409],
#                 {&quot;fill&quot;: true}
#             ).addTo(map_73a1acf1c344d463876d32a7d0f5e2d8);
#
#
#             var marker_49135bd3f67e7af312060c48f9991d81 = L.marker(
#                 [37.511293, 127.048409],
#                 {&quot;fill&quot;: true}
#             ).addTo(map_73a1acf1c344d463876d32a7d0f5e2d8);
#
#
#             var marker_4a4525ff0e31572aa18648be9c484dab = L.marker(
#                 [37.502117, 127.026672],
#                 {&quot;fill&quot;: true}
#             ).addTo(map_73a1acf1c344d463876d32a7d0f5e2d8);
#
#
#             var marker_e83c921facea30faddd09cd5c65920ee = L.marker(
#                 [37.50999, 127.061455],
#                 {&quot;fill&quot;: true}
#             ).addTo(map_73a1acf1c344d463876d32a7d0f5e2d8);
#
#
#             var marker_c89e41a43bd0cea22946b30c5b664a99 = L.marker(
#                 [37.518181, 127.045995],
#                 {&quot;fill&quot;: true}
#             ).addTo(map_73a1acf1c344d463876d32a7d0f5e2d8);

# %%
# 각 지점에서 '구'명 추출

gu_names = []

for addr in df['주소']:
    gu = addr.split()[1]
    gu_names.append(gu)

print(gu_names)
print(len(gu_names))
# Out:
# ['강남구', '강남구', '강남구', '강남구', '강남구', '강남구', '강남구', '강남구', '강남구', '강남구', '강남구', '강남구', '강남구', '강남구', '강남구', '강남구', '강남구', '강남구', '강남구', '강남구', '강남구', '강남구', '강남구', '강남구', '강남구', '강남구', '강남구', '강남구', '강남구', '강남구', '강남구', '강남구', '강남구', '강남구', '강남구', '강남구', '강남구', '강남구', '강남구', '강남구', '강남구', '강남구', '강남구', '강남구', '강남구', '강남구', '강남구', '강남구', '강남구', '강남구', '강남구', '강남구', '강남구', '강남구', '강남구', '강남구', '강남구', '강남구', '강남구', '강남구', '강남구', '강남구', '강남구', '강남구', '강남구', '강남구', '강남구', '강남구', '강남구', '강남구', '강남구', '강남구', '강남구', '강남구', '강남구', '강남구', '강남구', '강남구', '강남구', '강남구', '강남구', '강남구', '강남구', '강남구', '강남구', '강남구', '강남구', '강북구', '강북구', '강북구', '강북구', '강북구', '강북구', '강서구', '강서구', '강서구', '강서구', '강서구', '강서구', '강서구', '강서구', '강서구', '강서구', '강서구', '강서구', '강서구', '강서구', '강서구', '강서구', '강서구', '강서구', '강서구', '강서구', '강서구', '강서구', '강서구', '강서구', '강서구', '관악구', '관악구', '관악구', '관악구', '관악구', '관악구', '관악구', '관악구', '관악구', '관악구', '관악구', '관악구', '광진구', '광진구', '광진구', '광진구', '광진구', '광진구', '광진구', '광진구', '광진구', '광진구', '광진구', '광진구', '광진구', '광진구', '광진구', '광진구', '광진구', '광진구', '광진구', '금천구', '금천구', '금천구', '금천구', '금천구', '금천구', '금천구', '금천구', '금천구', '금천구', '금천구', '금천구', '금천구', '노원구', '노원구', '노원구', '노원구', '노원구', '노원구', '노원구', '노원구', '노원구', '노원구', '노원구', '노원구', '노원구', '노원구', '도봉구', '도봉구', '도봉구', '도봉구', '동작구', '동작구', '동작구', '동작구', '동작구', '동작구', '동작구', '동작구', '동작구', '동작구', '동작구', '마포구', '마포구', '마포구', '마포구', '마포구', '마포구', '마포구', '마포구', '마포구', '마포구', '마포구', '마포구', '마포구', '마포구', '마포구', '마포구', '마포구', '마포구', '마포구', '마포구', '마포구', '마포구', '마포구', '마포구', '마포구', '마포구', '마포구', '마포구', '마포구', '마포구', '마포구', '마포구', '마포구', '마포구', '마포구', '서대문구', '서대문구', '서대문구', '서대문구', '서대문구', '서대문구', '서대문구', '서대문구', '서대문구', '서대문구', '서대문구', '서대문구', '서대문구', '서대문구', '서대문구', '서대문구', '서대문구', '서대문구', '서대문구', '서대문구', '서대문구', '서대문구', '서초구', '서초구', '서초구', '서초구', '서초구', '서초구', '서초구', '서초구', '서초구', '서초구', '서초구', '서초구', '서초구', '서초구', '서초구', '서초구', '서초구', '서초구', '서초구', '서초구', '서초구', '서초구', '서초구', '서초구', '서초구', '서초구', '서초구', '서초구', '서초구', '서초구', '서초구', '서초구', '서초구', '서초구', '서초구', '서초구', '서초구', '서초구', '서초구', '서초구', '서초구', '서초구', '서초구', '서초구', '서초구', '서초구', '서초구', '서초구', '성북구', '성북구', '성북구', '성북구', '성북구', '성북구', '성북구', '성북구', '성북구', '성북구', '성북구', '성북구', '성북구', '성북구', '성북구', '송파구', '송파구', '송파구', '송파구', '송파구', '송파구', '송파구', '송파구', '송파구', '송파구', '송파구', '송파구', '송파구', '송파구', '송파구', '송파구', '송파구', '송파구', '송파구', '송파구', '송파구', '송파구', '송파구', '송파구', '송파구', '송파구', '송파구', '송파구', '송파구', '송파구', '송파구', '송파구', '송파구', '송파구', '양천구', '양천구', '양천구', '양천구', '양천구', '양천구', '양천구', '양천구', '양천구', '양천구', '양천구', '양천구', '양천구', '양천구', '양천구', '양천구', '양천구', '영등포구', '영등포구', '영등포구', '영등포구', '영등포구', '영등포구', '영등포구', '영등포구', '영등포구', '영등포구', '영등포구', '영등포구', '영등포구', '영등포구', '영등포구', '영등포구', '영등포구', '영등포구', '영등포구', '영등포구', '영등포구', '영등포구', '영등포구', '영등포구', '영등포구', '영등포구', '영등포구', '영등포구', '영등포구', '영등포구', '영등포구', '영등포구', '영등포구', '영등포구', '영등포구', '영등포구', '영등포구', '영등포구', '영등포구', '영등포구', '영등포구', '은평구', '은평구', '은평구', '은평구', '은평구', '은평구', '은평구', '은평구', '은평구', '은평구', '은평구', '은평구', '은평구', '종로구', '종로구', '종로구', '종로구', '종로구', '종로구', '종로구', '종로구', '종로구', '종로구', '종로구', '종로구', '종로구', '종로구', '종로구', '종로구', '종로구', '종로구', '종로구', '종로구', '종로구', '종로구', '종로구', '종로구', '종로구', '종로구', '종로구', '종로구', '종로구', '종로구', '종로구', '종로구', '종로구', '종로구', '종로구', '종로구', '종로구', '종로구', '종로구', '종로구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '중구', '강동구', '강동구', '강동구', '강동구', '강동구', '강동구', '강동구', '강동구', '강동구', '강동구', '강동구', '강동구', '강동구', '강동구', '강동구', '강동구', '강동구', '구로구', '구로구', '구로구', '구로구', '구로구', '구로구', '구로구', '구로구', '구로구', '구로구', '구로구', '구로구', '구로구', '구로구', '동대문구', '동대문구', '동대문구', '동대문구', '동대문구', '동대문구', '동대문구', '동대문구', '동대문구', '동대문구', '성동구', '성동구', '성동구', '성동구', '성동구', '성동구', '성동구', '성동구', '성동구', '성동구', '성동구', '성동구', '성동구', '성동구', '성동구', '용산구', '용산구' ...
# 600

# %%
df['시군구명'] = gu_names
df
# Out:
#          매장명                 위도                  경도  \
# 0    역삼아레나빌딩          37.501087          127.043069
# 1     논현역사거리          37.510178          127.022223
# 2    신사역성일빌딩         37.5139309         127.0206057
# 3     국기원사거리          37.499517          127.031495
# 4    대치재경빌딩R          37.494668          127.062583
# ..       ...                ...                 ...
# 595     사가정역          37.579594          127.087966
# 596      상봉역           37.59689           127.08647
# 597       묵동          37.615368          127.076633
# 598      양원역   37.6066536267232    127.106359790053
# 599      중화역  37.60170912407773  127.07841136432036
#
#                                         주소       전화번호       매장종류 시군구명
# 0                  서울특별시 강남구 언주로 425 (역삼동)  1522-3232  리저브 매장 2번  강남구
# 1                 서울특별시 강남구 강남대로 538 (논현동)  1522-3232  리저브 매장 2번  강남구
# 2                 서울특별시 강남구 강남대로 584 (논현동)  1522-3232  리저브 매장 2번  강남구
# 3                 서울특별시 강남구 테헤란로 125 (역삼동)  1522-3232  리저브 매장 2번  강남구
# 4               서울특별시 강남구 남부순환로 2947 (대치동)  1522-3232  리저브 매장 2번  강남구
# ..                                     ...        ...        ...  ...
# 595                      서울특별시 중랑구 면목로 310  1522-3232  리저브 매장 2번  중랑구
# 596                서울특별시 중랑구 망우로 307 (상봉동)  1522-3232  리저브 매장 2번  중랑구
# 597  서울특별시 중랑구 동일로 952 (묵동, 로프트원 태릉입구역) 1층  1522-3232  리저브 매장 2번  중랑구
# 598              서울특별시 중랑구 양원역로10길 3 (망우동)  1522-3232  리저브 매장 2번  중랑구
# 599                     서울특별시 중랑구 봉화산로 35   1522-3232  리저브 매장 2번  중랑구
#
# [600 rows x 7 columns]

# %%
# 구별 스타벅스 매장 수 계산

starbucks_count = df.pivot_table(index='시군구명',
                                 values='매장명',
                                 aggfunc='count').rename(columns={'매장명':'매장수'})

starbucks_count
# Out:
#       매장수
# 시군구명
# 강남구    87
# 강동구    17
# 강북구     6
# 강서구    25
# 관악구    12
# 광진구    19
# 구로구    14
# 금천구    13
# 노원구    14
# 도봉구     4
# 동대문구   10
# 동작구    11
# 마포구    35
# 서대문구   22
# 서초구    48
# 성동구    15
# 성북구    15
# 송파구    34
# 양천구    17
# 영등포구   41
# 용산구    25
# 은평구    13
# 종로구    40
# 중구     55
# 중랑구     8

# %%
# 거주자 수, 업체 수 등의 엑셀 파일과 결합하기

seoul_sgg = pd.read_excel('seoul_sgg_stat.xlsx', thousands=',')
seoul_sgg
# Out:
#     시군구코드  시군구명         위도          경도  스타벅스_매장수  주민등록인구  종사자수_x  사업체수_x  \
# 0   11320   도봉구  37.665861  127.031767         2  371095   68669   18455
# 1   11380   은평구  37.617612  126.922700         8  474165   87693   24179
# 2   11230  동대문구  37.583801  127.050700         8  374039  143858   32994
# 3   11590   동작구  37.496504  126.944307        11  407966  103915   19609
# 4   11545   금천구  37.460097  126.900155        11  262337  223058   30080
# 5   11530   구로구  37.495486  126.858121        11  449187  210506   37445
# 6   11110   종로구  37.599100  126.986149        37  177023  269106   40871
# 7   11305   강북구  37.646995  127.014716         5  342669   69787   18654
# 8   11260   중랑구  37.595379  127.093967         7  431283   99241   27287
# 9   11680   강남구  37.495985  127.066409        81  570913  711278   73590
# 10  11500   강서구  37.565762  126.822656        16  578257  199289   33273
# 11  11140    중구  37.557945  126.994190        53  138102  423808   66190
# 12  11740   강동구  37.549208  127.146482        15  490945  143061   30079
# 13  11215   광진구  37.548144  127.085753        16  386292  123689   24531
# 14  11440   마포구  37.562291  126.908780        32  392087  252534   36504
# 15  11650   서초구  37.476953  127.037810        47  432888  439963   47061
# 16  11290   성북구  37.606991  127.023218        13  484359  113893   24690
# 17  11350   노원구  37.655264  127.077120        12  614603  114736   25827
# 18  11710   송파구  37.504853  127.114482        32  689909  302517   45375
# 19  11410  서대문구  37.582037  126.935666        19  336490  111615   19612
# 20  11470   양천구  37.527062  126.856153        15  504928  119443   26297
# 21  11560  영등포구  37.520641  126.913924        34  440863  362524   44512
